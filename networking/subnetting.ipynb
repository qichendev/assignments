# %% [markdown]
# Requirement
# Lan1
# 128host=2^7
# /25=/(32-7)
# subnet192.18.6.0
# boardcasting192.18.5.127
# 192.18.5.0-192.18.5.126/25
# musk
# 255.255.255.192
#
# Lan2
# 62
# subnet192.18.5.128
# 192.18.5.129-192.18.5.191/26
# boardcast 192.18.5.192
#
# lan3
# 28
# subnet192.18.5.193
# 192.18.5.194-192.18.5.224/27
# boardcast 192.18.5.225
#
# link1
# subnet192.18.5.226
# 192.18.5.227-192.18.5.228/30
# boardcast192.18.5.229
#
# link2
# subnet192.18.5.230
# 192.18.5.231-192.18.5.232/30
# boardcast192.18.5.233
#
# link1
# subnet192.18.5.234
# 192.18.5.235-192.18.5.236/30
# boardcast192.18.5.237
#
# link1
# subnet192.18.5.238
# 192.18.5.239-192.18.5.240/30
# boardcast192.18.5.241
