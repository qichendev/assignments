# %%
name = 'Harpreet'
for name in name:
    print(name)
# Out:
# H
# a
# r
# p
# r
# e
# e
# t

# %%
city = 'Sarnia'
index = 0
while index < len(city):
    print(city[index])
    index += 1
# Out:
# S
# a
# r
# n
# i
# a

# %%
message = 'Hello ' + 'World' + '!'
print(message)

# %%
text = 'I love ice cream'
if 'ice' in text:
    print('The string "ice" was found.')
else:
    print('The string "ice" was not found.')

# %%
my_string='w'*5

print(my_string)
# Out:
# wwwww

# %%
my_string = 'One two three four'
print(my_string.split())
date = '2022/2/22'
print(date.split('/'))
# Out:
# ['One', 'two', 'three', 'four']
# ['2022', '2', '22']

# %%
my_string = 'One two three four \t five'
print(my_string)
# Out:
# One two three four 	 five

# %%
my_string = 'One two three four \n five \n'
print(my_string)
# Out:
# One two three four
#  five

# %%
my_string = 'One two three four \n five \n'
print(my_string * 3)
# Out:
# One two three four
#  five
# One two three four
#  five
# One two three four
#  five

# %%
my_string = 'One two three four \n five \n'
print(my_string.capitalize())
# Out:
# One two three four
#  five

# %%
my_string = 'THIS IS'
print(my_string.casefold())
# Out:
# this is

# %%
my_string = 'THIS IS'
print(my_string.count('I'))
print(my_string.count('S'))
# Out:
# 2
# 2
