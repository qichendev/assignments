# %%
my_set = {"windows", "linux", "mac"}
print(type(my_set))
# Out:
# <class 'set'>

# %%
my_set = {"pc os":"windows", "server":"linux", "mine":"mac"}
print(type(my_set))
# Out:
# <class 'dict'>

# %%
my_dict = {"first_name": "William", "job_title": "Python Instructor"}
print(my_dict)

print(type(my_dict))
print(my_dict['first_name'])
print(my_dict['job_title'])
my_dict['job_title'] = "Python Developer"
print(my_dict['job_title'])
print(my_dict)
# Out:
# {'first_name': 'William', 'job_title': 'Python Instructor'}
# <class 'dict'>
# William
# Python Instructor
# Python Developer
# {'first_name': 'William', 'job_title': 'Python Developer'}

# %%
# primitive data types (They can only hold one value)
my_var1 = "This is a string"
my_grades = 80
print(type(my_var1))
print(type(my_grades))

my_Ist = ["Font", "size", 17]
my_grades1 = [85, 89, 93, 99, 100, 85]
my_grades_nested_list = [[89,90,91], [75,21], [80,90,75,95]]
print(type(my_grades1))
print(type(my_grades_nested_list))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'list'>
# <class 'list'>

# %%
my_grades = [85, 89, 93, 99]
print("before changing the value", ", my _grades")
my_grades[0] = 92
print("after changing the value", my_grades)
my_grades[0] = "A+"
print("after changing the value", my_grades)
my_grades.remove("A+")
print("after removing", my_grades)
del my_grades[0]
print("after removing", my_grades)
# Out:
# before changing the value , my _grades
# after changing the value [92, 89, 93, 99]
# after changing the value ['A+', 89, 93, 99]
# after removing [89, 93, 99]
# after removing [93, 99]

# %%
my_grades = ("strings", [1,2,3], (12,34,31), 85, 89, 93, 99)
print(type(my_grades))
print(type(my_grades[0]))
print(type(my_grades[1]))
print(type(my_grades[2]))
print(type(my_grades[3]))
# Out:
# <class 'tuple'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'int'>

# %%
my_dict = {"first_name": "William", "job_title": "Python Instructor"}
for key, value in my_dict.items():
    print(key, value)
# Out:
# first_name William
# job_title Python Instructor

# %%
myset = set([1, 2, 3])
if 1 in myset:
    print('The value 1 is in the set.')
# Out:
# The value 1 is in the set.

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
 
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {3, 4}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
 
difference_set = set1.difference(set2)
print(difference_set)
# Out:
# {1, 2}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
 
symmetric_difference_set = set1.symmetric_difference(set2)
print(symmetric_difference_set)
# Out:
# {1, 2, 5, 6}
