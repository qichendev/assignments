# %%
import random
number = random.randint(1, 100)
print(number)
# Out:
# 47

# %%
for i in range(1, 10):
    number = random.randint(1, 100)
    print(number)
# Out:
# 71
# 24
# 71
# 31
# 2
# 72
# 23
# 18
# 36

# %%
for i in range(1, 10):
    number = random.randrange(1, 100)
    print(i, number)
# Out:
# 1 51
# 2 20
# 3 82
# 4 13
# 5 24
# 6 34
# 7 12
# 8 98
# 9 33

# %%
for i in range(1, 10):
    print(random.randrange(0, 101, 10))
# Out:
# 70
# 90
# 100
# 100
# 50
# 40
# 70
# 50
# 30

# %%
random.random()
# Out:
# 0.5602059357214483

# %%
random.uniform(1, 10)
# Out:
# 4.260901518907312

# %%
random.seed(10)
for i in range(1, 10):
    print(random.randint(1, 100))
# Out:
# 74
# 5
# 55
# 62
# 74
# 2
# 27
# 60
# 63

# %%
random.seed(10)
for i in range(1, 10):
    print(random.randint(1, 100))
# Out:
# 74
# 5
# 55
# 62
# 74
# 2
# 27
# 60
# 63

# %%
def sum(a, b):
    return a + b

print(sum(1, 2))
# Out:
# 3

# %%
def get_regular_price():
    return input("Enter the regular price: ")

price = get_regular_price()
print(price)
# Out:
# 203

# %%
def get_name():
    return input("Enter your name: ")

get_name()

# %%
def is_even(number):
    return number % 2 == 0

print(is_even(1))
# Out:
# False

# %%
model = int(input("Enter the mode: "))
while (model != 100 and model != 200):
    print("Invalid mode")
    model = int(input("Enter the mode: "))
print("Valid mode")
# Out:
# Invalid mode
# Valid mode

# %%
def get_name():
    first_name = input("Enter your first name: ")
    last_name = input("Enter your last name: ")
    return first_name, last_name

first_name, last_name = get_name()
print(first_name, last_name)
# Out:
# qi chen

# %%
import math

print(math.pi)

print(math.pi * 2)
# Out:
# 3.141592653589793
# 6.283185307179586
