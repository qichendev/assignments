# %%
a = 10
a
# Out:
# 10

# %%
a==10
# Out:
# True

# %%
a>=11
# Out:
# False

# %%
# decision structure
if a==10:
    print('a equals 10')
else:
    print('a is not equal 10')
# Out:
# a equals 10

# %%
bonus=0
sales=int(input("please input sales"))
if sales > 50000:
    bonus = 500.0
print(bonus)
# Out:
# 500.0

# %%
temperature=float(input("please enter your temperature"))
if temperature < 40:
    print("A little cold, isn't it?")
else:
    print("Nice weather we're having.")
# Out:
# Nice weather we're having.

# %%
my_name = 'chen qi'
what_s_your_name=input('what\'s your name?')
my_name==what_s_your_name
# Out:
# False

# %%
print(what_s_your_name)
# Out:
# chenqi

# %%
salary=float(input("Please input your salary"))
years_on_job=float(input("Please input your years on job"))
if salary >= 30000:
    if years_on_job >= 2:
        print("You qualify for the loan.")
    else:
        print("You must have been on your current job for at least two years to qualify.")
else:
    print('You must earn at least $30,000 per year to qualitfy.')
# Out:
# You must earn at least $30,000 per year to qualitfy.

# %%
score = float(input("Please enter your score: "))
if score >= 90:
    print('Your grade is A.')
elif score >= 80:
    print('Your grade is B.')
elif score >= 70:
    print('Your grade is C.')
elif score >= 60:
    print('Your grade is D.')
else:
    print('Your grade is F.')
# Out:
# Your grade is F.

# %%
my_boolean = False
boolean_again = True
print(type(my_boolean))
# Out:
# <class 'bool'>

# %%
a = 10
b = 20
if (a == b):
    print("a and b are the same")
else:
    print("a and b are not the same")
# Out:
# a and b are not the same

# %%
a = 30
b - 20
if (a == b):
    print("a and b are the same")
elif (a < b):
    print("a is smaller than b")
elif (a > b):
    print("a is greater than b")
# Out:
# a is greater than b

# %%
grade = 100
if (grade >= 80):
    print("you have got A")
    if (grade >= 90):
        print("you have got A+")
# Out:
# you have got A
# you have got A+

# %%
my_first_variable = 10
my_second_variable = 30
c = my_first_variable / my_second_variable
d = my_first_variable * my_second_variable
print(c, type(c))
print(d, type(d))
# Out:
# 0.3333333333333333 <class 'float'>
# 300 <class 'int'>

# %%
my_first_variable = 20
my_second_variable = 7
remainder = my_first_variable % my_second_variable
print("Our remainder is", remainder, "and it is of type", type(remainder))
quotient = my_first_variable // my_second_variable
print("Our quotient is", quotient, "and it is of type", type(quotient))
# Out:
# Our remainder is 6 and it is of type <class 'int'>
# Our quotient is 2 and it is of type <class 'int'>

# %%
a = 20
a += 10
print(a)
a -= 5
print(a)
a *= 2
print(a)
# Out:
# 30
# 25
# 50
