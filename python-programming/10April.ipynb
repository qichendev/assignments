# %%
temperature=int(input("Enter temperature"))
if temperature<15:
    print("A little cold, isn't it?")
elif temperature>25:
    print("A little warm, isn't it?")
else:
    print("Nice weather we're having.")
# Out:
# A little cold, isn't it?

# %%
names = ['Abed', 'Bill', 'Charlie']
for n in names:
    print(n)
# Out:
# Abed
# Bill
# Charlie

# %%
amounts = [12,3,0,9]

total=0

for n in amounts:

    total += n

print("Total : ", total)
# Out:
# Total :  24

# %%
def check_input(test_val,test_list):

    return test_val in test_list

print(check_input(0, [1, 2, 0, 3, 4]))
# Out:
# True

# %%
lucky_numbers = [10, 7, 1, 20]
def is_lucky(num):
    return num in lucky_numbers
print(is_lucky(10))
# Out:
# True

# %%
fulName = "Qi none Chen"
middleName = fulName[3:7]
print(middleName)
# Out:
# none
